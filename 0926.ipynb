# %% [markdown]
# <a href="https://colab.research.google.com/github/hyunaeee/KU-SW-Academy/blob/main/0926.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
DHTML <- AJAX <- JS XHR;

Client           Server
Req ---------->
    <---------- text/html
DOM1
Req ---------->
    <---------- text/html
DOM2(*)
Req ---------->
    <---------- ? data
변형된 DOM2
어디서, 어떻게 가져올건인가?
----> (브라우저) 네트워크 히스토리 (XHR/JS) 찾는 연습(API,)

Client              Server(X)
쿠키   ---  변수 ---    세션
로그인(서버 기능) -> 쿠키를 생성(예제), 활용(LMS)
쿠키; name=value;도메인,경로,시간,...
ResponseHeaders['Set-cookie'] -> 서버 쿠키를 클라이언트 기록
RequestHeaders['Cookie'] -> 서버로 전달 될 쿠키
; 네이버 로그인 ; SocialMedia(Meta-Instagram)
from requests import request, get, post
from requests.sessions import Session
from requests.compat import *
from bs4 import BeautifulSoup

dom = BeautifulSoup(
    get('https://nid.naver.com/nidlogin.login').text, 'lxml')
form = dom.select('form')[0]
form.attrs
{'id': 'frmNIDLogin',
 'name': 'frmNIDLogin',
 'target': '_top',
 'autocomplete': 'off',
 'action': 'https://nid.naver.com/nidlogin.login',
 'method': 'POST'}
params = {}
for tag in form.select('input[name]'):
    params[tag.attrs["name"]] = tag.attrs["value"]\
                                if tag.has_attr('value') else ''
params['id'] = '아이디'
params['pw'] = '어쩌고저쩌고'
resp = post(form.attrs['action'], params)
c = ''' 본인 네이버 쿠키 복붙 '''

NC = dict()

for l in c.splitlines()[1:]:
    NC[l.split()[0]] = l.split()[1]
NC.keys()
dict_keys(['tooltip_shoppingbox_close', 'NID_SES', 'NV_WETR_LOCATION_RGN_M', 'page_uid', 'JSESSIONID', 'NV_WETR_LAST_ACCESS_RGN_M', 'm_loc', 'SB_MODE', 'NID_JKL', 'NID_AUT', 'nx_ssl', 'PM_CK_loc', 'ASID', 'nid_slevel', 'NNB', 'nid_buk'])
url = 'https://mail.naver.com/json/list'
params = {
    'folderSN':5,
    'page':1,
    'viewMode':'time',
    'previewMode':1,
    'sortField':1,
    'sortType':0,
    'u':'gon0121'
}
resp = post(url, params, cookies=NC)
resp.request.url
POST:'https://mail.naver.com/json/list?folderSN=0&page=1&viewMode=time&previewMode=1&sortField=1&sortType=0&u=gon0121'
data X
'https://mail.naver.com/json/list'
resp.request.body
'folderSN=0&page=1&viewMode=time&previewMode=1&sortField=1&sortType=0&u=gon0121'
for mail in resp.json()['mailData']:
    print(mail['subject'])
(광고)비상주사무실임대! 신청만해도 평생 최저가!
(광고)다이어트 고민이신가요? 지방흡입 49% 파격할인 진행합니다~!
(광고) 고객을 찾아드립니다 🌸CPA환영🌸 인터넷 이사짐 결혼정보회사 법인영업 판매 등
(광고) 2023년 하반기 정부 정책자금 - 추경예산확보! 꼭 받아가세요
(광고) 🌸 27세 ~ 65세까지! 내 결혼정보회사 등급은?! 간단 테스트로 조회해보세요🌸
(광고) 💸🤔 내가 낼 세금이 너무 많다고 느낄 땐? 📉✉️
(광고) 🍀 정책자금 및 저금리 은행대출 특별지원 안내 🍀
(광고) ★150만 회원 돌파기념★ &#39;100% 전액지원+100% 전액환급&#39; 삼성/LG 최신가전 100% 전액지원 받아가세요.
(광고) 갤럭시 Z Flip l Fold 95%할인, 재고소진시작! 지금 구매찬스입니다.
(광고) Since 1948! 18번 완당집 추석 특별전
(광고) 🌸 27세 ~ 65세까지! 내 결혼정보회사 등급은?! 간단 테스트로 조회해보세요🌸
(광고) 가족사진! 10년 후 참 찍길 잘했다 느낄 추억여행 한장! 특별 이벤트를 놓치지 마세요. (흔한 무료 사진 아닌 프리미엄 가족 사진)
(광고) &#39;4대보험 가입 근로자 대상&#39; 우선지원 채무통합 전환 지원센터!!
(광고)영업 광고비 부담이신가요? 대표님께 CPA 광고 제안드립니다
(광고) ★공장보유/유통마진 ZERO 특가공급★  .자사공장. 국내최저가!누적판매 500만장
c = ''' LMS 쿠키 '''

LMS = {}
for l in c.splitlines()[1:]:
    LMS[l.split()[0]] = l.split()[1]
url = 'https://lms.sunde41.net/qna/detail/64'
resp = get(url, cookies=LMS)
dom = BeautifulSoup(resp.text, 'lxml')
params = {
    'description':'류기곤 답변'
}
post(url, params, cookies=LMS)
<Response [200]>
# 로그인 할 수 있는 사이트 로그인 해보기(10시20분)
sess = Session()
from datetime import datetime

url = 'https://www.instagram.com/api/v1/web/accounts/login/ajax/'

params = {
    'enc_password':'',
    'optIntoOneTap': 'false',
    'queryParams': '{}',
    'trustedDeviceRecords': '{}',
    'username': 'gon0121+dev@gmail.com'
}

t = int(datetime.now().timestamp())
pw = 'toinstagram'

params['enc_password'] = f'#PWD_INSTAGRAM_BROWSER:0:{t}:{pw}'
resp.status_code, resp.headers
(403,
 {'Set-Cookie': 'csrftoken=A2jRmXJqg44LsgS5Vod8tLJA2NEHBu1K; Domain=.instagram.com; expires=Tue, 24-Sep-2024 01:51:39 GMT; Max-Age=31449600; Path=/; Secure', 'Retry-After': '1', 'x-ig-peak-time': '1', 'x-ig-request-elapsed-time-ms': '53', 'Access-Control-Expose-Headers': 'X-IG-Set-WWW-Claim', 'x-aed': '132', 'x-ig-cache-control': 'no-cache', 'x-ig-push-state': 'c2', 'X-XSS-Protection': '0', 'X-Content-Type-Options': 'nosniff', 'cross-origin-opener-policy': 'same-origin-allow-popups;report-to="coop"', 'origin-trial': 'AuqWincgAuXeuu3KypEMnrrFEJHySaesyJS3EaIH40zvafzrU0Irhb7+5QwZpOqMZrPTjgvFl7Z5jJgy1dNAcQMAAAB6eyJvcmlnaW4iOiJodHRwczovL2luc3RhZ3JhbS5jb206NDQzIiwiZmVhdHVyZSI6IkNyb3NzT3JpZ2luT3BlbmVyUG9saWN5UmVwb3J0aW5nIiwiZXhwaXJ5IjoxNjEzNDExNjYyLCJpc1N1YmRvbWFpbiI6dHJ1ZX0=', 'cross-origin-resource-policy': 'cross-origin', 'report-to': '{"group": "coep", "max_age": 86400, "endpoints": [{"url": "/security/coep_report/"}]},{"group": "coop", "max_age": 86400, "endpoints": [{"url": "/security/coop_report/"}]}', 'cross-origin-embedder-policy-report-only': 'require-corp;report-to="coep"', 'content-security-policy': "report-uri https://www.instagram.com/security/csp_report/; default-src 'self' https://www.instagram.com; img-src data: blob: https://*.fbcdn.net https://*.instagram.com https://*.cdninstagram.com https://*.facebook.com https://*.fbsbx.com https://*.threads.net https://*.giphy.com; font-src data: https://*.fbcdn.net https://*.instagram.com https://*.cdninstagram.com; media-src 'self' blob: https://www.instagram.com https://*.cdninstagram.com https://*.fbcdn.net; manifest-src 'self' https://www.instagram.com; script-src 'self' https://instagram.com https://www.instagram.com https://*.www.instagram.com https://*.cdninstagram.com wss://www.instagram.com https://*.facebook.com https://*.fbcdn.net https://*.facebook.net 'unsafe-inline' 'unsafe-eval' blob:; style-src 'self' https://*.www.instagram.com https://www.instagram.com 'unsafe-inline'; connect-src 'self' https://instagram.com https://www.instagram.com https://*.www.instagram.com https://graph.instagram.com https://*.graph.instagram.com https://i.instagram.com/graphql_www https://graphql.instagram.com https://*.cdninstagram.com https://api.instagram.com https://i.instagram.com https://*.i.instagram.com https://*.od.instagram.com https://i.threads.net https://*.od.threads.net wss://www.instagram.com wss://edge-chat.instagram.com https://*.facebook.com https://*.fbcdn.net https://*.facebook.net chrome-extension://boadgeojelhgndaghljhdicfkmllpafd blob:; worker-src 'self' blob: https://www.instagram.com; frame-src 'self' https://instagram.com https://www.instagram.com https://*.instagram.com https://staticxx.facebook.com https://www.facebook.com https://web.facebook.com https://connect.facebook.net https://m.facebook.com https://*.fbsbx.com; object-src 'none'; upgrade-insecure-requests", 'X-Frame-Options': 'SAMEORIGIN', 'Expires': 'Sat, 01 Jan 2000 00:00:00 GMT', 'Pragma': 'no-cache', 'Cache-Control': 'private, no-cache, no-store, must-revalidate', 'Strict-Transport-Security': 'max-age=31536000', 'Content-Language': 'en', 'Vary': 'Accept-Language, Cookie', 'Date': 'Tue, 26 Sep 2023 01:51:39 GMT', 'Content-Type': 'application/json; charset=utf-8', 'X-FB-Debug': 'OPZNy1KP40uaA9Yt2vcq6HjkbbEUolZzpGl28aWCL+O0UxfPiBJbWsDgRZo8k8EESxnFGtSGw3n/fvsYHReFNQ==', 'x-ig-origin-region': 'eag', 'Alt-Svc': 'h3=":443"; ma=86400', 'Connection': 'close', 'Content-Length': '61'})
resp.text
'{"message":"CSRF token missing or incorrect","status":"fail"}'
resp.request.headers
{'User-Agent': 'python-requests/2.28.1', 'Accept-Encoding': 'gzip, deflate, br', 'Accept': '*/*', 'Connection': 'keep-alive', 'Cookie': 'csrftoken=A2jRmXJqg44LsgS5Vod8tLJA2NEHBu1K; ig_did=8B2C34AB-E051-4A2F-8BE3-5B2D57DA92F4; ig_nrcb=1; mid=ZRI4jwAEAAHg6NG93xWN5VhW_LPv', 'Content-Length': '170', 'Content-Type': 'application/x-www-form-urlencoded'}
#PWD_INSTAGRAM_BROWSER:
10: => 암호화
1695692275: =>
    => PW
AZ5QAOLd3xmCzj2u80kuah3tT05qYZRmlkElTdRdKfwfVkcr0pUIeDl8OAhkircj89voyfMlk9lBBhqmb781B/kIPHyqsK6h23/Vny42Md1DHexyFUtN+ljE0EOtg8j3jAztJzMH3Zl7E7QT2uD5

#PWD_INSTAGRAM_BROWSER:0:시간:비밀번호
url = 'https://www.instagram.com/accounts/login/'
resp = get(url)
resp.status_code
200
import re

# {\\"csrf_token\\":\\"GWwYNHVMbyOVaNHqakJYvnsepcHq386T\\"
token = re.search(r'csrf_token\\":\\"(.+?)\\"', resp.text).group(1)
{'x-csrftoken':token}
{'x-csrftoken': 'GWwYNHVMbyOVaNHqakJYvnsepcHq386T'}
sess.cookies.clear()
resp = sess.post(url, params, headers={'x-csrftoken':token})
resp.status_code
200
resp.text
'{"user":true,"userId":"49814451599","authenticated":true,"oneTapPrompt":true,"status":"ok"}'
resp.headers['set-cookie']
'csrftoken=KSlS0maAjDyvnnGeHWY09eHUtQj6IOhy; Domain=.instagram.com; expires=Tue, 24-Sep-2024 01:58:27 GMT; Max-Age=31449600; Path=/; Secure, rur="EAG\\05449814451599\\0541727229507:01f73fcd8d787b2573cbfff1d5abafa8645fa6087d49920dab562ec6132467e3185ac0d1"; Domain=.instagram.com; HttpOnly; Path=/; SameSite=Lax; Secure, mid=ZRI6wAAEAAElDDV_fezsVYo7BF5L; Domain=.instagram.com; expires=Wed, 30-Oct-2024 01:58:27 GMT; Max-Age=34560000; Path=/; Secure, ds_user_id=49814451599; Domain=.instagram.com; expires=Mon, 25-Dec-2023 01:58:27 GMT; Max-Age=7776000; Path=/; Secure, ig_did=BF4A1E58-7C9D-4090-A074-51AD92277D48; Domain=.instagram.com; expires=Wed, 25-Sep-2024 01:58:27 GMT; HttpOnly; Max-Age=31536000; Path=/; Secure, sessionid=49814451599%3ARPNPrvEMGMoqZF%3A26%3AAYeglKqy3emYhFi5zU24jvTB_CxYa2MI5syb-3JOmQ; Domain=.instagram.com; expires=Wed, 25-Sep-2024 01:58:27 GMT; HttpOnly; Max-Age=31536000; Path=/; Secure'
sess.cookies
<RequestsCookieJar[Cookie(version=0, name='csrftoken', value='KSlS0maAjDyvnnGeHWY09eHUtQj6IOhy', port=None, port_specified=False, domain='.instagram.com', domain_specified=True, domain_initial_dot=True, path='/', path_specified=True, secure=True, expires=1727143105, discard=False, comment=None, comment_url=None, rest={}, rfc2109=False), Cookie(version=0, name='ds_user_id', value='49814451599', port=None, port_specified=False, domain='.instagram.com', domain_specified=True, domain_initial_dot=True, path='/', path_specified=True, secure=True, expires=1703469505, discard=False, comment=None, comment_url=None, rest={}, rfc2109=False), Cookie(version=0, name='ig_did', value='BF4A1E58-7C9D-4090-A074-51AD92277D48', port=None, port_specified=False, domain='.instagram.com', domain_specified=True, domain_initial_dot=True, path='/', path_specified=True, secure=True, expires=1727229505, discard=False, comment=None, comment_url=None, rest={'HttpOnly': None}, rfc2109=False), Cookie(version=0, name='mid', value='ZRI6wAAEAAElDDV_fezsVYo7BF5L', port=None, port_specified=False, domain='.instagram.com', domain_specified=True, domain_initial_dot=True, path='/', path_specified=True, secure=True, expires=1730253505, discard=False, comment=None, comment_url=None, rest={}, rfc2109=False), Cookie(version=0, name='rur', value='"EAG\\05449814451599\\0541727229507:01f73fcd8d787b2573cbfff1d5abafa8645fa6087d49920dab562ec6132467e3185ac0d1"', port=None, port_specified=False, domain='.instagram.com', domain_specified=True, domain_initial_dot=True, path='/', path_specified=True, secure=True, expires=None, discard=True, comment=None, comment_url=None, rest={'HttpOnly': None, 'SameSite': 'Lax'}, rfc2109=False), Cookie(version=0, name='sessionid', value='49814451599%3ARPNPrvEMGMoqZF%3A26%3AAYeglKqy3emYhFi5zU24jvTB_CxYa2MI5syb-3JOmQ', port=None, port_specified=False, domain='.instagram.com', domain_specified=True, domain_initial_dot=True, path='/', path_specified=True, secure=True, expires=1727229505, discard=False, comment=None, comment_url=None, rest={'HttpOnly': None}, rfc2109=False)]>
첫페이지 -> 기입(ID,PW) -> 로그인 버튼
1. 첫페이지
2. CSRF_TOKEN
3. X-csrftoken=2
4. encpassword => 형식 => #PWD_:0:시간:비밀번호
5. ajax POST 4만든 params => req.body(data={4}, headers={3})
6. 요청
url = 'https://www.instagram.com'
resp = get(url)
token = re.search(r'csrf_token\\":\\"(.+?)\\"', resp.text).group(1)
{'x-csrftoken':token}
{'x-csrftoken': 'LQrGChPHMYS7p8hbWiBCTeglpz80iFof'}
from datetime import datetime

url = 'https://www.instagram.com/api/v1/web/accounts/login/ajax/'

params = {
    'enc_password':'',
    'optIntoOneTap': 'false',
    'queryParams': '{}',
    'trustedDeviceRecords': '{}',
    'username': 'gon0121+dev@gmail.com'
}

t = int(datetime.now().timestamp())
pw = 'toinstagram'

params['enc_password'] = f'#PWD_INSTAGRAM_BROWSER:0:{t}:{pw}'
sess.cookies.clear()
resp = sess.post(url, params, headers={'x-csrftoken':token})
resp.status_code, resp.headers['content-type']
(200, 'application/json; charset=utf-8')
resp.json()
{'user': True,
 'userId': '49814451599',
 'authenticated': True,
 'oneTapPrompt': True,
 'status': 'ok'}
url = 'https://www.instagram.com/api/graphql'

params = {
    'av': '17841449787986806',
    '__d': 'www',
    '__user': '0',
    '__a': '1',
    '__req': '25',
    '__hs': '19626.HYP:instagram_web_pkg.2.1..0.1',
    'dpr': '1',
    '__ccg': 'UNKNOWN',
    '__rev': '1008847885',
    '__s': ':zooi2j:yfttye',
    '__hsi': '7282960505140112951',
    '__dyn': '7xeUmwlEnwn8K2WnFw9-2i5U4e0yoW3q32360CEbotw50x609vCwjE1xoswIwuo2awlU-cw5Mx62G3i1ywOwv89k2C1Fwc60AEC7U2czXwae4UaEW2G1NwwwNwKwHw8Xxm16wUwtEvU1aUbpEbUGdG1QwTwFwIw8O321LwTwKG1pg661pwr86C1mwraCg',
    '__csr': 'gX3Yp2lPjTPNtrSWuIz_mAWGXnAJqjJ5G9zGgLqAKRKbjVAAuAgzKnhlykZdqC-DhHVKUCHhV-h4ABWGrKuEG21kEmybAKu00hf2481Dk2e3Ka9a0Ao0aQ4boaETwRc5X5Q1dwsU4uu0cJo3kgd41lwgcM20w3f89UT809-yS01j9w3QE',
    '__comet_req': '7',
    'fb_dtsg': 'NAcPiwx3YwzTxNuyJp2Aj3yULAmfkz6D7uufeIVUSuMYrw2TYEoYwUA:17855905060073950:1695696249',
    'jazoest': '26569',
    'lsd': 'kdXluk0e9qlYkWH73atDKX',
    '__spin_r': '1008847885',
    '__spin_b': 'trunk',
    '__spin_t': '1695696382',
    'fb_api_caller_class': 'RelayModern',
    'fb_api_req_friendly_name': 'PolarisSearchBoxRefetchableQuery',
    'variables': '',
    'server_timestamps': 'true',
    'doc_id': '6460896210645763'
}

data = {"data":{"context":"blended","include_reel":"true","query":"ㅇㅇㅇㅇㅇㅇ","rank_token":"","search_surface":"web_top_search"},"hasQuery":"true"}
data['data']['query'] = '카리나'
import json
params['variables'] = json.dumps(data)
url = 'https://www.instagram.com/api/v1/feed/user/katarinabluu/username/?count=12'
resp = sess.get(url, headers={'x-csrftoken':sess.cookies.get('csrftoken')})
resp.json()
{'message': 'useragent mismatch', 'status': 'fail'}
